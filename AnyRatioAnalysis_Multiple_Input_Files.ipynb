# %% [markdown]
# # Orbitrap Data Analysis Code
# #### Developer: ssz & tc; Last modified: March 27, 2021

# %% [markdown]
# ### Load the analysis code

# %%
run DataAnalyzer.py

# %% [markdown]
# ### Process a folder of data

# %%
#Set up the inputs

#Folder with FT Statistic-ified files. All the files need to be processed using the same metrics.
inputSampleFolder = "singleFragmentTestFolder"
#inputStandardFolder = "Test_Folder"
#Whether or not you are accounting for a GC or column elution
gc_elution_on = False
#Time frames for the GC elution
peakTimeFrames = [(5.65,5.85), (6.82,7.62), (9.74,10.04), (10.00,10.30), (13.74,14.04)]
#stdpeakTimeFrames = [(6.65,6.78), (7.85, 8.12), (9.95,10.15), (10.21,10.4), (12.32,12.47)]
#samplepeakTimeFrames = [(6.65,6.78), (7.85, 8.12), (9.95,10.15), (12.32,12.47)]

MetM1Dict = {'133':['D','13C','33S','Unsub']}

#Choose the most abundant peak for each fragment. The order should be the same as the order of the key/value pairs
#in the above dictionary. This peak will be the denominator of the ratios for this fragment. 
fragmentMostAbundant = ['13C']

#Extract from dictionary. 
massStr = []
fragmentIsotopeList = []
for i, v in MetM1Dict.items():
    massStr.append(i)
    fragmentIsotopeList.append(v)
    
#Any specific properties you want to cull on
cullOn = None
#Multiple of SD you want to cull beyond for the cullOn property
cull_amount = 2
#Whether you want to cull zero scans
cullZeroScans = False
#Whether you want to calculate weighted averages based on NL height (specifically designed for GC elution but widely applicable!)
weightByNLHeight = False
#Whether you want to output each file as you process it, and where you want it to go:
fileOutputPath = None

#Let's do it! This populates both output for each file and also statistics for all the files.
SampleOutput,SampleStatsOutput=calc_Folder_Output(inputSampleFolder, 
                                                 cullOn=cullOn, 
                                                 cullZeroScansOn=cullZeroScans, 
                                                 gcElutionOn=gc_elution_on, 
                                                 weightByNLHeight=weightByNLHeight, 
                                                 gcElutionTimes = peakTimeFrames,  
                                                 cullAmount=cull_amount, 
                                                 fragmentIsotopeList = fragmentIsotopeList, 
                                                 fragmentMostAbundant = fragmentMostAbundant, 
                                                 NL_over_TIC=0.10,  
                                                 fileCsvOutputPath=fileOutputPath)

#StdOutput,StdStatsOutput=_calcFolderOutput(inputStandardFolder, cullOn=cullOn, cullZeroScansOn=cullZeroScans, gcElutionOn=gc_elution_on, weightByNLHeight=weightByNLHeight, gcElutionTimes = peakTimeFrames,  cullAmount=cull_amount, isotopeList = isotopeList, NL_over_TIC=0.10, omitRatios = omitRatios, fileCsvOutputPath=fileOutputPath)
# Out:
# singleFragmentTestFolder/20201214_07_5 uL Methionine 5uM M+1 5e4 133_1.xlsx
# singleFragmentTestFolder/20201214_07_5 uL Methionine 5uM M+1 5e4 133_2.xlsx
# singleFragmentTestFolder/20201214_07_5 uL Methionine 5uM M+1 5e4 133_3.xlsx

# %% [markdown]
# Print output for all files, fragments, and isotope ratios

# %%
SampleOutput
# Out:
#                                           FileNumber Fragment IsotopeRatio  \
# 1  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0      33S/13C
# 4  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0      33S/13C
# 7  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0      33S/13C
# 0  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0        D/13C
# 3  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0        D/13C
# 6  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0        D/13C
# 2  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0    Unsub/13C
# 5  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0    Unsub/13C
# 8  singleFragmentTestFolder/20201214_07_5 uL Meth...    134.0    Unsub/13C
#
#     Average    StdDev  StdError  RelStdError    TICVar  TIC*ITVar  \
# 1  0.129877  0.013675  0.000569     0.004380  0.053156   0.073499
# 4  0.129877  0.013675  0.000569     0.004380  0.053156   0.073499
# 7  0.129877  0.013675  0.000569     0.004380  0.053156   0.073499
# 0  0.017388  0.004636  0.000193     0.011090  0.053156   0.073499
# 3  0.017388  0.004636  0.000193     0.011090  0.053156   0.073499
# 6  0.017388  0.004636  0.000193     0.011090  0.053156   0.073499
# 2  0.062651  0.008824  0.000367     0.005859  0.053156   0.073499
# 5  0.062651  0.008824  0.000367     0.005859  0.053156   0.073499
# 8  0.062651  0.008824  0.000367     0.005859  0.053156   0.073499
#
#      TIC*ITMean
# 1  76163.067474
# 4  76163.067474
# 7  76163.067474
# 0  76163.067474
# 3  76163.067474
# 6  76163.067474
# 2  76163.067474
# 5  76163.067474
# 8  76163.067474

# %% [markdown]
# Print statistical summary

# %%
SampleStatsOutput
# Out:
# Fragment         134.0
# IsotopeRatio   33S/13C     D/13C Unsub/13C
# Avg R Val     0.129877  0.017388  0.062651
# N             3.000000  3.000000  3.000000
# StdDev        0.000000  0.000000  0.000000
# StdError      0.000000  0.000000  0.000000
# RelStdError   0.000000  0.000000  0.000000

# %% [markdown]
# At the moment, there is no automatic "warning" raised if the fragment dictionary "MetM3Dict" is defined incorrectly. Processing a single file, you may see this in the data plots, but not here. Recommend adding this in the future, and being careful to run these as single files first for the time being.

# %%
#Set up the inputs

#Folder with FT Statistic-ified files. All the files need to be processed using the same metrics.
inputSampleFolder = "multipleFragmentTestFolder"
#inputStandardFolder = "Test_Folder"
#Whether or not you are accounting for a GC or column elution
gc_elution_on = False
#Time frames for the GC elution
peakTimeFrames = [(5.65,5.85), (6.82,7.62), (9.74,10.04), (10.00,10.30), (13.74,14.04)]
#stdpeakTimeFrames = [(6.65,6.78), (7.85, 8.12), (9.95,10.15), (10.21,10.4), (12.32,12.47)]
#samplepeakTimeFrames = [(6.65,6.78), (7.85, 8.12), (9.95,10.15), (12.32,12.47)]

MetM3Dict = {'133':['13C-18O','18O-33S','D-34S','13C-34S','34S'],
             '104':['D-34S','13C-34S','15N-34S','34S','13C','33S','Unsub'],
            '102':['13C-18O','18O','D','13C','15N','Unsub'],
             '88':['34S-D','13C-34S','34S','13C','33S','Unsub'],
             '74High':['13C-18O','18O','D','17O','13C','15N','Unsub'],
             '74Low':['13C-18O','18O','D','17O','13C','15N','Unsub'],
             '61':['D-34S','13C-34S','34S','13C','33S','Unsub'],
             '56':['D','13C','15N','Unsub']}

#Choose the most abundant peak for each fragment. The order should be the same as the order of the key/value pairs
#in the above dictionary. This peak will be the denominator of the ratios for this fragment. 
fragmentMostAbundant = ['13C-34S','13C-34S','13C','13C-34S','13C','Unsub','34S','13C']

#Extract from dictionary. 
massStr = []
fragmentIsotopeList = []
for i, v in MetM3Dict.items():
    massStr.append(i)
    fragmentIsotopeList.append(v)
    
#Any specific properties you want to cull on
cullOn = None
#Multiple of SD you want to cull beyond for the cullOn property
cull_amount = 2
#Whether you want to cull zero scans
cullZeroScans = False
#Whether you want to calculate weighted averages based on NL height (specifically designed for GC elution but widely applicable!)
weightByNLHeight = False
#Whether you want to output each file as you process it, and where you want it to go:
fileOutputPath = None

#Let's do it! This populates both output for each file and also statistics for all the files.
SampleOutput,SampleStatsOutput=calc_Folder_Output(inputSampleFolder, 
                                                 cullOn=cullOn, 
                                                 cullZeroScansOn=cullZeroScans, 
                                                 gcElutionOn=gc_elution_on, 
                                                 weightByNLHeight=weightByNLHeight, 
                                                 gcElutionTimes = peakTimeFrames,  
                                                 cullAmount=cull_amount, 
                                                 fragmentIsotopeList = fragmentIsotopeList, 
                                                 fragmentMostAbundant = fragmentMostAbundant, 
                                                 NL_over_TIC=0.10,  
                                                 fileCsvOutputPath=fileOutputPath)

#StdOutput,StdStatsOutput=_calcFolderOutput(inputStandardFolder, cullOn=cullOn, cullZeroScansOn=cullZeroScans, gcElutionOn=gc_elution_on, weightByNLHeight=weightByNLHeight, gcElutionTimes = peakTimeFrames,  cullAmount=cull_amount, isotopeList = isotopeList, NL_over_TIC=0.10, omitRatios = omitRatios, fileCsvOutputPath=fileOutputPath)
# Out:
# multipleFragmentTestFolder/Multiple_Fragment_Example_20201217_06_Methionine M3 Frag 250 uM 2e5 NCE 60_01.xlsx
# multipleFragmentTestFolder/Multiple_Fragment_Example_20201217_06_Methionine M3 Frag 250 uM 2e5 NCE 60_02.xlsx
# multipleFragmentTestFolder/Multiple_Fragment_Example_20201217_06_Methionine M3 Frag 250 uM 2e5 NCE 60_03.xlsx

# %%
SampleOutput
# Out:
#                                            FileNumber Fragment   IsotopeRatio  \
# 10  multipleFragmentTestFolder/Multiple_Fragment_E...    105.1    13C-18O/13C
# 50  multipleFragmentTestFolder/Multiple_Fragment_E...    105.1    13C-18O/13C
# 90  multipleFragmentTestFolder/Multiple_Fragment_E...    105.1    13C-18O/13C
# 13  multipleFragmentTestFolder/Multiple_Fragment_E...    105.1        15N/13C
# 53  multipleFragmentTestFolder/Multiple_Fragment_E...    105.1        15N/13C
# ..                                                ...      ...            ...
# 56  multipleFragmentTestFolder/Multiple_Fragment_E...     90.0    34S/13C-34S
# 96  multipleFragmentTestFolder/Multiple_Fragment_E...     90.0    34S/13C-34S
# 19  multipleFragmentTestFolder/Multiple_Fragment_E...     90.0  Unsub/13C-34S
# 59  multipleFragmentTestFolder/Multiple_Fragment_E...     90.0  Unsub/13C-34S
# 99  multipleFragmentTestFolder/Multiple_Fragment_E...     90.0  Unsub/13C-34S
#
#      Average    StdDev  StdError  RelStdError    TICVar  TIC*ITVar  \
# 10  0.078491  0.012211  0.000362     0.004606  0.048634   0.063890
# 50  0.078491  0.012211  0.000362     0.004606  0.048634   0.063890
# 90  0.078491  0.012211  0.000362     0.004606  0.048634   0.063890
# 13  0.073049  0.011732  0.000347     0.004755  0.048634   0.063890
# 53  0.073049  0.011732  0.000347     0.004755  0.048634   0.063890
# ..       ...       ...       ...          ...       ...        ...
# 56  0.351787  0.026235  0.000777     0.002208  0.128948   0.135488
# 96  0.351787  0.026235  0.000777     0.002208  0.128948   0.135488
# 19  0.025912  0.006035  0.000179     0.006895  0.128948   0.135488
# 59  0.025912  0.006035  0.000179     0.006895  0.128948   0.135488
# 99  0.025912  0.006035  0.000179     0.006895  0.128948   0.135488
#
#        TIC*ITMean
# 10  311327.729185
# 50  311327.729185
# 90  311327.729185
# 13  311327.729185
# 53  311327.729185
# ..            ...
# 56  307041.597721
# 96  307041.597721
# 19  307041.597721
# 59  307041.597721
# 99  307041.597721
#
# [120 rows x 10 columns]

# %%
SampleStatsOutput
# Out:
# Fragment           105.1                                               107.1  \
# IsotopeRatio 13C-18O/13C   15N/13C   18O/13C     D/13C Unsub/13C 13C/13C-34S
# Avg R Val       0.078491  0.073049  0.034477  0.021591  0.248128    0.087835
# N               3.000000  3.000000  3.000000  3.000000  3.000000    3.000000
# StdDev          0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# StdError        0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# RelStdError     0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
#
# Fragment                                                            ...  \
# IsotopeRatio 15N-34S/13C-34S 33S/13C-34S 34S/13C-34S D-34S/13C-34S  ...
# Avg R Val           0.074429    0.013923    0.260915      0.031405  ...
# N                   3.000000    3.000000    3.000000      3.000000  ...
# StdDev              0.000000    0.000000    0.000000      0.000000  ...
# StdError            0.000000    0.000000    0.000000      0.000000  ...
# RelStdError         0.000000    0.000000    0.000000      0.000000  ...
#
# Fragment          77.1                                                90.0  \
# IsotopeRatio   15N/13C   17O/13C   18O/13C     D/13C Unsub/13C 13C/13C-34S
# Avg R Val     0.094339  0.007567  0.020854  0.022095  0.664856    0.077901
# N             3.000000  3.000000  3.000000  3.000000  3.000000    3.000000
# StdDev        0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# StdError      0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# RelStdError   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
#
# Fragment
# IsotopeRatio 33S/13C-34S 34S-D/13C-34S 34S/13C-34S Unsub/13C-34S
# Avg R Val       0.012314      0.018194    0.351787      0.025912
# N               3.000000      3.000000    3.000000      3.000000
# StdDev          0.000000      0.000000    0.000000      0.000000
# StdError        0.000000      0.000000    0.000000      0.000000
# RelStdError     0.000000      0.000000    0.000000      0.000000
#
# [5 rows x 40 columns]
